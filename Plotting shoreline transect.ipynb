# %% [markdown]
# # Shoreline Data for the transects

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
print(os.getcwd())
# Out:
# C:\Users\Vhaid\OneDrive\Desktop\MS 274\Projects

# %%
transects_folder = 'Transects'

# read in the SST timeseries
transects_timeseries = np.genfromtxt(os.path.join(transects_folder,
                               'raw_transect_time_series.csv'), delimiter=',')

# %%
plt.plot(transects_timeseries[:,-1], 'r-')
plt.ylabel('SST ($^{\circ}$C)')
#plt.gca().set_xticklabels([])
#plt.xlim([2019,2024])
plt.grid(linestyle='--',linewidth=0.5)
